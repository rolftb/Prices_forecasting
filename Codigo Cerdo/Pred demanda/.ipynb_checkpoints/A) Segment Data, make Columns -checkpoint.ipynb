# %% [markdown]
# # Información previa
#
# ## Diseño y esquema codigo
#
# 1. Exploracion de los datos
#     1. Segmentar los datos por los cluster de clientes
#         - **Estudio de los comportamientos de demanda de cada cluster generico:**
#
#         Plantear curvas de comportamiento de compra de cada cliente para cada cluster de clientes, de esta forma se visualizara si los clientes poseen estacionalidades similares a lo que respecta a las compras.
#
#         - curvas etacionales de los precios de compra de cada cliente, para cada cluster de clientes
# 2. Creación de atributos
#     1. Stock
#         - Ajustar hora y valores
#     2. Demanda
#         - Definir valores.
#         - Ajustar por medio del groupby, para que sea de cada cluster.
#         -

# %% [markdown]
# ## Temas a considerar de los datos
#
# ### Data Cluster
#
# Los segmentos según lo analisado coinciden en las siguientes caracteristicas

# %% [markdown]
# ![title](img/Segmento_de_clientes.png)

# %% [markdown]
# Los segmentos más llamativos a nivel demanda son **el 4 y el 2**
#
# * **Segmento 2 MAYORISTA**
# * **Segmento 4 FRECUENTES**

# %% [markdown]
# # Package Install & Open Data

# %% [markdown]
# ## Import

# %%
# =============================================================================
# Importar paquetes y abrir Data
# =============================================================================

#gestion DF
import pandas as pd

#Funciones mat y matricicales
import numpy as np

#ploteo simple
import matplotlib.pyplot as plt

# Graficas bonitas
from plotnine import *

#para ajustar las fechas
import datetime

#para calcular el skew de un array() o list()
from scipy.stats import skew 

#mode function
import statistics

# %%
import random

# %% [markdown]
# ##  Data Facturación

# %%
# =============================================================================
# Ajuste de los datos
# =============================================================================

col_names=pd.read_csv("Data/(column)Facturac_2017_2020.csv",
                    encoding="utf-8",sep=";",nrows=0).columns
types_dict = {col: str for col in col_names}

Data = pd.read_csv("Data/(column)Facturac_2017_2020.csv",
                   encoding="utf-8",sep=";",dtype=types_dict)

# %% [markdown]
# ### Ajuste facturaciones

# %%
# =============================================================================
# Ajustar la data
# =============================================================================
def Ajuste_data(data):
    df=data.copy()
    # Funciones para eliminar los putos y cambiar las , por .
    def change_num_point(x):
        x=str(x)
        return x.replace('.', '')
    def change_num_coma(x):
        x=str(x)
        return x.replace(',', '.')
    
    #proceso iterativo, 
    for i in ['Kilos Venta KG','Venta Neta CLP','Precio Promedio CLP']:
    # se elimina el punto definido para los miles
        df[i]=df[i].apply(change_num_point)
        # se reemplaza la coma por un punto, para definir los decimales correctamente
        df[i]=df[i].apply(change_num_coma)
        # Se pasa de ser un str a un int
        df[i]=df[i].astype('int64')

    #Separacion fecha
    df['Semana']=df['Año natural/Semana'].str.split('.', expand=True)[[0]]
    df['Año']=df['Año natural/Semana'].str.split('.', expand=True)[[1]]

    df['Semana']=df['Semana'].astype('int64')
    df['Año']=df['Año'].astype('int64')
    
    #
    df["Día natural"] = df["Día natural"].apply(lambda x: 
                                                datetime.datetime.strptime(x,
                                                                           '%d.%m.%Y').date())
    return df

# %%
data=Ajuste_data(Data)
#data=<data[data['Año']>2018]

# %% [markdown]
# ### Exploración

# %%
data.dtypes
# Out:
# Material                       object
# Tipo de cliente                object
# Zona de ventas                 object
# Zona de ventas.1               object
# Oficina de Ventas Unifica      object
# Oficina de Ventas Unifica.1    object
# Subtipo de cliente             object
# Cluster                        object
# Cliente - Local                object
# Cliente - Local.1              object
# Mes                            object
# Año natural/Semana             object
# Día natural                    object
# Día de la semana               object
# Kilos Venta KG                  int64
# Venta Neta CLP                  int64
# Precio Promedio CLP             int64
# Semana                          int64
# Año                             int64
# dtype: object

# %%
data.head(3)
# Out:
#   Material Tipo de cliente Zona de ventas Zona de ventas.1  \
# 0  1010078     Tradicional           Z001         Santiago
# 1  1010078     Tradicional           Z001         Santiago
# 2  1010078     Tradicional           Z001         Santiago
#
#   Oficina de Ventas Unifica Oficina de Ventas Unifica.1 Subtipo de cliente  \
# 0                Huechuraba                        T101      Emprendedores
# 1                Huechuraba                        T101      Emprendedores
# 2                Huechuraba                        T101      Emprendedores
#
#    Cluster                  Cliente - Local Cliente - Local.1 Mes  \
# 0  Clásico   Gonzalez Ahumada Paola Eugenia        3200116471   4
# 1  Clásico   Gonzalez Ahumada Paola Eugenia        3200116471   8
# 2  Clásico   Gonzalez Ahumada Paola Eugenia        3200116471  10
#
#   Año natural/Semana Día natural Día de la semana  Kilos Venta KG  \
# 0            17.2020  2020-04-24               VI              22
# 1            34.2020  2020-08-18               MA              22
# 2            43.2019  2019-10-25               VI              22
#
#    Venta Neta CLP  Precio Promedio CLP  Semana   Año
# 0           25380                 1150      17  2020
# 1           29304                 1320      34  2020
# 2           26532                 1200      43  2019

# %%
data['Año'].unique()
# Out:
# array([2020, 2019, 2021, 2018, 2017], dtype=int64)

# %%
#data[data['Precio Promedio CLP']>=2018]

# %% [markdown]
# ##  Data Clientes

# %%
Cluster = pd.read_csv("Data/Cluster_clientes.csv",
                          encoding="utf-8",sep=";",dtype={'Cliente - Local.1': 'str'})

# %% [markdown]
# ### Exploración Clientes

# %%
Cluster.head(4)
# Out:
#   Cliente - Local.1 Oficina de Ventas Unifica Subtipo de cliente Cluster BW  \
# 0        3200116471                Huechuraba      Emprendedores    Clásico
# 1        3200159471                Huechuraba      Emprendedores    Clásico
# 2        3200126536                Huechuraba      Emprendedores    Clásico
# 3        3200100206                Huechuraba      Emprendedores    Clásico
#
#    Frecuencia mes promedio  Delta dia promedio  Skew Delta dia  \
# 0                 0.176471          149.000000        0.000000
# 1                 0.916667           23.100000        1.847072
# 2                 0.555556           55.473684        1.674688
# 3                 0.375000          100.000000        0.000000
#
#    Kilos Venta promedio  Covarianza del lote  \
# 0                  22.0             0.000000
# 1                  22.0             0.000000
# 2                  21.5             0.104003
# 3                  22.0             0.000000
#
#    Precio Pond CLP \n Tipo de Semana 4  ...  \
# 0                          1302.931580  ...
# 1                          1335.604383  ...
# 2                          1383.204509  ...
# 3                          1429.559995  ...
#
#    Precio Pond CLP \n Tipo de Semana 1  \
# 0                          1302.931580
# 1                          1267.719446
# 2                          1320.452780
# 3                          1490.000000
#
#    Kilos Venta KG promedio \n Tipo de Semana 1  \
# 0                                         22.0
# 1                                         22.0
# 2                                         22.0
# 3                                         22.0
#
#    Precio Pond CLP \n Tipo de Semana 0  \
# 0                          1150.000000
# 1                          1180.250000
# 2                          1265.693126
# 3                          1231.000000
#
#    Kilos Venta KG promedio \n Tipo de Semana 0  Tipo de Semana 4  \
# 0                                         22.0          0.666667
# 1                                         22.0          1.291667
# 2                                         22.0          1.962500
# 3                                         22.0          2.666667
#
#    Tipo de Semana 3  Tipo de Semana 2  Tipo de Semana 1  Tipo de Semana 0  \
# 0               0.0          1.000000          0.666667               1.0
# 1               1.0          1.666667          1.000000               1.5
# 2               1.5          1.750000          1.600000               3.0
# 3               2.0          2.666667          4.000000               2.0
#
#    identified_clusters
# 0                    3
# 1                    1
# 2                    0
# 3                    0
#
# [4 rows x 25 columns]

# %% [markdown]
# #### Ploteo de la frecuencia de compra

# %% [markdown]
# ## Incluir Columna Cluster(Segmento de cliente)

# %%
DF_ventas=pd.merge(Cluster[['Cliente - Local.1','identified_clusters']] , data  
     , how='right')

# %%
DF_ventas.tail(3)
# Out:
#        Cliente - Local.1  identified_clusters Material Tipo de cliente  \
# 208988             78915                  0.0  1010078     Tradicional
# 208989             78915                  0.0  1010078     Tradicional
# 208990        3200088892                  NaN  1010078     Tradicional
#
#        Zona de ventas Zona de ventas.1 Oficina de Ventas Unifica  \
# 208988           Z001         Santiago       Sucursal Miraflores
# 208989           Z001         Santiago       Sucursal Miraflores
# 208990           Z001         Santiago      Vendedores San Pablo
#
#        Oficina de Ventas Unifica.1 Subtipo de cliente      Cluster  \
# 208988                        T122         Vendedores  Sin asignar
# 208989                        T122         Vendedores  Sin asignar
# 208990                        TE16         Vendedores  Sin asignar
#
#                             Cliente - Local Mes Año natural/Semana  \
# 208988           Ventas Sucursal Miraflores  10            41.2018
# 208989           Ventas Sucursal Miraflores  12            51.2017
# 208990  Soc de Transp Susana Medina Escobar   4            15.2020
#
#        Día natural Día de la semana  Kilos Venta KG  Venta Neta CLP  \
# 208988  2018-10-10               MI              44           72963
# 208989  2017-12-21               JU              22           35280
# 208990  2020-04-09               JU              22           26400
#
#         Precio Promedio CLP  Semana   Año
# 208988                 1650      41  2018
# 208989                 1600      51  2017
# 208990                 1200      15  2020

# %% [markdown]
# # Estudio sobre los Segmentos

# %% [markdown]
# Grafica de  dispersion de la demanda de cada cliente

# %% [markdown]
# ## Analisis sobre Segemento FRECUENTE

# %%
# GEnero el DF
Cluster_df_vol=DF_ventas[DF_ventas['identified_clusters']==4]

# %%
Cluster_df_vol.shape
# Out:
# (148515, 20)

# %%
Cluster_df_vol.columns
# Out:
# Index(['Cliente - Local.1', 'identified_clusters', 'Material',
#        'Tipo de cliente', 'Zona de ventas', 'Zona de ventas.1',
#        'Oficina de Ventas Unifica', 'Oficina de Ventas Unifica.1',
#        'Subtipo de cliente', 'Cluster', 'Cliente - Local', 'Mes',
#        'Año natural/Semana', 'Día natural', 'Día de la semana',
#        'Kilos Venta KG', 'Venta Neta CLP', 'Precio Promedio CLP', 'Semana',
#        'Año'],
#       dtype='object')

# %%
Cluster_df_vol.head(1)
# Out:
#    Cliente - Local.1  identified_clusters Material Tipo de cliente  \
# 30        3200076085                  4.0  1010078     Tradicional
#
#    Zona de ventas Zona de ventas.1 Oficina de Ventas Unifica  \
# 30           Z001         Santiago                Huechuraba
#
#    Oficina de Ventas Unifica.1 Subtipo de cliente  Cluster  \
# 30                        T101      Emprendedores  Clásico
#
#                         Cliente - Local Mes Año natural/Semana Día natural  \
# 30  Aguilera Morales Alejandra del carr   2            05.2021  2021-02-01
#
#    Día de la semana  Kilos Venta KG  Venta Neta CLP  Precio Promedio CLP  \
# 30               LU              22           30496                 1370
#
#     Semana   Año
# 30       5  2021

# %%
Clientes_del_cluster=Cluster_df_vol['Cliente - Local.1'].unique()
Clientes_del_cluster
# Out:
# array(['3200076085', '3200136525', '3200167199', ..., '3200164715',
#        '3200172313', '3200123613'], dtype=object)

# %%
Cluster_df_vol=Cluster_df_vol[Cluster_df_vol['Año']>2018]

# %% [markdown]
# ### Graficas

# %%
#'#008000'
rand_color= '#00'+str( random. randint(1000,8000))
rand_color
# Out:
# '#005331'

# %%
270/12
# Out:
# 22.5

# %%
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día natural'
# sketch in data

for i in Clientes_del_cluster:
    df_C=Cluster_df_vol[Cluster_df_vol['Cliente - Local.1']==i].reset_index()
    df_C.sort_values(by=[x], inplace=True)
    rand_color= '#00'+str( random. randint(1000,8000))
    plt.plot(df_C[x], df_C[y], color=rand_color)
    
df_C=Cluster_df_vol.groupby(x).mean()[y].reset_index()
plt.plot(df_C[x], df_C[y], 'r')

# set title & labels
plt.title(('Compras clientes Cluster '+'4'), fontsize=18)
plt.ylabel(y, fontsize=13)
plt.xlabel('Time (year)', fontsize=13)

# display graph
plt.show()

# %%
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día natural'
CDf=Cluster_df_vol[Cluster_df_vol[x]>datetime.date(2019, 12, 31)]
# sketch in data

for i in Clientes_del_cluster:
    df_C=CDf[CDf['Cliente - Local.1']==i].reset_index()
    df_C.sort_values(by=[x], inplace=True)
    plt.plot(df_C[x], df_C[y], 'b')
    
df_C=CDf.groupby(x).mean()[y].reset_index()
plt.plot(df_C[x], df_C[y], 'r')

# set title & labels
plt.title(('Compras clientes Cluster '+'4'), fontsize=18)
plt.ylabel(y, fontsize=13)
plt.xlabel('Time (year)', fontsize=13)

# display graph
plt.show()

# %%
df_C.columns
# Out:
# Index(['Día natural', 'Kilos Venta KG'], dtype='object')

# %%
df_C.head(1)
# Out:
#   Día natural  Kilos Venta KG
# 0  2020-01-02        55.57377

# %% [markdown]
# ### Por dia de la semana

# %%
D_Sem={'JU':4, 'LU':1, 'VI':5, 'MA':2, 'MI':3, 'SA':6,'DO':7}
def change_sem(x):
        x=D_Sem[x]
        return x
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día de la semana'
# sketch in data


for i in Clientes_del_cluster:
    df_C=Cluster_df_vol[Cluster_df_vol['Cliente - Local.1']==i].reset_index()
    df_C[x]=df_C[x].apply(change_sem)
    df_C=df_C.groupby(x).mean()[y].reset_index()
    df_C.sort_values(by=[x], inplace=True)
    plt.plot(df_C[x], df_C[y], 'b')


df_C=Cluster_df_vol.groupby(x).mean()[y].reset_index()
df_C[x]=df_C[x].apply(change_sem)
df_C.sort_values(by=[x], inplace=True)
plt.plot(df_C[x], df_C[y], 'r')

# set title & labels
plt.title('Promedio de ventas de los clientes por dia de la semana', fontsize=18)
plt.ylabel('Promedio de' + y, fontsize=13)
plt.xlabel(x, fontsize=13)

# display graph
plt.show()

# %% [markdown]
# #### Lote compra promedio Dia semana

# %%
D_Sem={'JU':4, 'LU':1, 'VI':5, 'MA':2, 'MI':3, 'SA':6,'DO':7}
def change_sem(x):
        x=D_Sem[x]
        return x
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día de la semana'
# sketch in data

"""
for i in Clientes_del_cluster:
    df_C=Cluster_df_vol[Cluster_df_vol['Cliente - Local.1']==i].reset_index()
    df_C[x]=df_C[x].apply(change_sem)
    df_C=df_C.groupby(x).mean()[y].reset_index()
    df_C.sort_values(by=[x], inplace=True)
    plt.plot(df_C[x], df_C[y], 'b')
"""
df_C=Cluster_df_vol.groupby(x).mean()[y].reset_index()
df_C[x]=df_C[x].apply(change_sem)
df_C.sort_values(by=[x], inplace=True)
plt.plot(df_C[x], df_C[y], 'r')

# set title & labels
plt.title('Promedio del cluster '+'frecuente'+' por dia de la semana', fontsize=18)
plt.ylabel('Promedio de' + y, fontsize=13)
plt.xlabel(x, fontsize=13)

# display graph
plt.show()

# %%
D_Sem={'JU':4, 'LU':1, 'VI':5, 'MA':2, 'MI':3, 'SA':6,'DO':7}
def change_sem(x):
        x=D_Sem[x]
        return x
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día de la semana'
# sketch in data

"""
for i in Clientes_del_cluster:
    df_C=Cluster_df_vol[Cluster_df_vol['Cliente - Local.1']==i].reset_index()
    df_C[x]=df_C[x].apply(change_sem)
    df_C=df_C.groupby(x).mean()[y].reset_index()
    df_C.sort_values(by=[x], inplace=True)
    plt.plot(df_C[x], df_C[y], 'b')
"""

df_C=Cluster_df_vol.groupby(x).sum()[y].reset_index()
df_C[x]=df_C[x].apply(change_sem)
df_C.sort_values(by=[x], inplace=True)
plt.plot(df_C[x], df_C[y], 'r')

# set title & labels
plt.title(' Ventas totales del cluster '+'frecuente'+' por dia de la semana', fontsize=18)
plt.ylabel('Totales de' + y, fontsize=13)
plt.xlabel(x, fontsize=13)

# display graph
plt.show()

# %% [markdown]
# # Stokc
#
# Esta data posee los volumenes de stock de santiago, para el trutro de pollo

# %% [markdown]
# ## Data

# %%
col_names=pd.read_csv("Data/last_down/Stock STGO 1010078.csv",
                    encoding="utf-8",sep=";",nrows=0).columns
types_dict = {col: str for col in col_names}

Data_stock = pd.read_csv("Data/last_down/Stock STGO 1010078.csv",
                   encoding="utf-8",sep=";",dtype=types_dict)

# %%
# =============================================================================
# Ajustar la data
# =============================================================================
def Ajuste_data(data):
    df=data.copy()
    # Funciones para eliminar los putos y cambiar las , por .
    def change_num_point(x):
        x=str(x)
        return x.replace('.', '')
    def change_num_coma(x):
        x=str(x)
        return x.replace(',', '.')
    
    #proceso iterativo, 
    for i in ['Stock']:
    # se elimina el punto definido para los miles
        df[i]=df[i].apply(change_num_point)
        # se reemplaza la coma por un punto, para definir los decimales correctamente
        df[i]=df[i].apply(change_num_coma)
        # Se pasa de ser un str a un int
        #df[i]=df[i].astype('int64')
        df[i]=df[i].astype('float64')

    #Separacion fecha
    df['Semana']=df['Año natural/Semana'].str.split('.', expand=True)[[0]]
    df['Año']=df['Año natural/Semana'].str.split('.', expand=True)[[1]]

    df['Semana']=df['Semana'].astype('int64')
    df['Año']=df['Año'].astype('int64')
    
    #
    df["Día natural"] = df["Día natural"].apply(lambda x: 
                                                datetime.datetime.strptime(x,
                                                                           '%d.%m.%Y').date())
    return df

# %%
Data_stock=Ajuste_data(Data_stock)

# %%
Data_stock.tail()
# Out:
#      Sector Material Zona de ventas Oficina de ventas  Oficina de ventas.1  \
# 1431  Pollo  1010078       Santiago              T122  Sucursal Miraflores
# 1432  Pollo  1010078       Santiago              T122  Sucursal Miraflores
# 1433  Pollo  1010078       Santiago              T122  Sucursal Miraflores
# 1434  Pollo  1010078       Santiago              T122  Sucursal Miraflores
# 1435  Pollo  1010078       Santiago              T122  Sucursal Miraflores
#
#      Año natural/Semana Día natural    Stock  Semana   Año
# 1431            16.2021  2021-04-21  38695.1      16  2021
# 1432            16.2021  2021-04-22  69045.9      16  2021
# 1433            16.2021  2021-04-23  58284.5      16  2021
# 1434            16.2021  2021-04-24  68294.9      16  2021
# 1435            17.2021  2021-04-26  57257.9      17  2021

# %% [markdown]
# ## Stock vs Demanda(Venta)

# %%
#=======================================
# groupby para estimar el volumen de STOCK
#=======================================

G_stock=Data_stock.groupby('Día natural').sum().reset_index()
G_stock.head()
# Out:
#   Día natural     Stock  Semana   Año
# 0  2019-11-27  208560.8     192  8076
# 1  2019-11-28  165123.1     192  8076
# 2  2019-11-29  138677.0     192  8076
# 3  2019-11-30  129420.3     192  8076
# 4  2019-12-02  132351.0     196  8076

# %%
#=======================================
# groupby para estimar LA DEMANDA TOTAL
#=======================================

G_data=data.groupby('Día natural').sum().reset_index()
G_data.head()
# Out:
#   Día natural  Kilos Venta KG  Venta Neta CLP  Precio Promedio CLP  Semana  \
# 0  2017-01-03            7809         7405757                70348      60
# 1  2017-01-04           10212        12333853               188933     148
# 2  2017-01-05            9441        11247762               170490     132
# 3  2017-01-06           16562        20375239               268723     208
# 4  2017-01-07            7937         9952646               174179     134
#
#       Año
# 0  121020
# 1  298516
# 2  266244
# 3  419536
# 4  270278

# %%
DF_VS=pd.merge(G_data[['Día natural', 'Kilos Venta KG']] , G_stock[['Día natural', 'Stock']]  
     , how='right')
DF_VS.sort_values(by=['Día natural'], inplace=True)
DF_VS.head()
# Out:
#   Día natural  Kilos Venta KG     Stock
# 0  2019-11-27         19736.0  208560.8
# 1  2019-11-28         44687.0  165123.1
# 2  2019-11-29         27747.0  138677.0
# 3  2019-11-30         24920.0  129420.3
# 4  2019-12-02         16344.0  132351.0

# %%
# frame up w/ grid
plt.figure(figsize=(26,8))
plt.grid(linestyle='-.')
y='Kilos Venta KG'
x='Día natural'
# sketch in data


plt.plot(DF_VS[x], DF_VS[y], 'b')

plt.plot(DF_VS[x], DF_VS['Stock'], 'r')

# set title & labels
plt.title('Relación demanda Canal Tradicional y volumen de Stock', fontsize=18)
plt.ylabel(y, fontsize=13)
plt.xlabel(x, fontsize=13)

# display graph
plt.show()

# %% [markdown]
# Realizar este mismo grafico pero considerando la demanda de cada canal de ventas, para evaluar cuales fueron los pick en ventad del canal tradicional dado la caida de algun otro canal.

# %% [markdown]
# # Stock Vida ultil

# %%
fillN='Stock Vida ultil 101078 Z01'
col_names=pd.read_csv("Data/last_down/"+fillN+".csv",
                    encoding="utf-8",sep=";",nrows=0).columns
types_dict = {col: str for col in col_names}

Data_stock = pd.read_csv("Data/last_down/"+fillN+".csv",
                   encoding="utf-8",sep=";",dtype=types_dict)

# %%
# =============================================================================
# Ajustar la data
# =============================================================================
def Ajuste_data(data):
    df=data.copy()
    # Funciones para eliminar los putos y cambiar las , por .
    def change_num_point(x):
        x=str(x)
        return x.replace('.', '')
    def change_num_coma(x):
        x=str(x)
        return x.replace(',', '.')
    
    #proceso iterativo, 
    for i in ['Stock']:
    # se elimina el punto definido para los miles
        df[i]=df[i].apply(change_num_point)
        # se reemplaza la coma por un punto, para definir los decimales correctamente
        df[i]=df[i].apply(change_num_coma)
        # Se pasa de ser un str a un int
        #df[i]=df[i].astype('int64')
        df[i]=df[i].astype('float64')

    #Separacion fecha
    df['Semana']=df['Año natural/Semana'].str.split('.', expand=True)[[0]]
    df['Año']=df['Año natural/Semana'].str.split('.', expand=True)[[1]]

    df['Semana']=df['Semana'].astype('int64')
    df['Año']=df['Año'].astype('int64')
    
    #
    df["Día natural"] = df["Día natural"].apply(lambda x: 
                                                datetime.datetime.strptime(x,
                                                                           '%d.%m.%Y').date())
    return df

# %%
Data_stock=Ajuste_data(Data_stock)

# %%
Data_stock['Vida Útil Restante']=Data_stock['Vida Útil Restante'].astype('int64')

# %% [markdown]
# ### Demanda dia CT

# %%
G_data=data.groupby('Día natural').sum().reset_index()
G_data.head()
# Out:
#   Día natural  Kilos Venta KG  Venta Neta CLP  Precio Promedio CLP  Semana  \
# 0  2017-01-03            7809         7405757                70348      60
# 1  2017-01-04           10212        12333853               188933     148
# 2  2017-01-05            9441        11247762               170490     132
# 3  2017-01-06           16562        20375239               268723     208
# 4  2017-01-07            7937         9952646               174179     134
#
#       Año
# 0  121020
# 1  298516
# 2  266244
# 3  419536
# 4  270278

# %% [markdown]
# ### Merge

# %%
Data_stock.dtypes
# Out:
# Sector                  object
# Material                object
# Zona de ventas          object
# Oficina de ventas       object
# Oficina de ventas.1     object
# Año natural/Semana      object
# Día natural             object
# Vida Útil Restante       int64
# Stock                  float64
# Semana                   int64
# Año                      int64
# dtype: object

# %%
Data_stock.columns#.head()
# Out:
# Index(['Sector', 'Material', 'Zona de ventas', 'Oficina de ventas',
#        'Oficina de ventas.1', 'Año natural/Semana', 'Día natural',
#        'Vida Útil Restante', 'Stock', 'Semana', 'Año'],
#       dtype='object')

# %% [markdown]
# #### Vida ultil restante promedio ponderado

# %%
def change_num_point(x):
    x['Vida Útil Restante']*x['Stock']
    return x.replace('.', '')

# %%
Data_stock['Vida Útil Restante Promedio']=Data_stock['Vida Útil Restante']*Data_stock['Stock']

# %%
G_stock=Data_stock.groupby(['Día natural']).sum().reset_index()
G_stock.head()
# Out:
#   Día natural  Vida Útil Restante     Stock  Semana   Año  \
# 0  2019-11-27                  32  208560.8     192  8076
# 1  2019-11-28                  33  165123.1     192  8076
# 2  2019-11-29                  36  138677.0     192  8076
# 3  2019-11-30                  35  129420.3     192  8076
# 4  2019-12-02                  29  132351.0     196  8076
#
#    Vida Útil Restante Promedio
# 0                    1705598.0
# 1                    1379638.1
# 2                    1248093.0
# 3                    1107666.7
# 4                     990749.8

# %%
G_stock['Vida Útil Restante Promedio']=G_stock['Vida Útil Restante Promedio']/G_stock['Stock']
G_stock.head()
# Out:
#   Día natural  Vida Útil Restante     Stock  Semana   Año  \
# 0  2019-11-27                  32  208560.8     192  8076
# 1  2019-11-28                  33  165123.1     192  8076
# 2  2019-11-29                  36  138677.0     192  8076
# 3  2019-11-30                  35  129420.3     192  8076
# 4  2019-12-02                  29  132351.0     196  8076
#
#    Vida Útil Restante Promedio
# 0                     8.177941
# 1                     8.355210
# 2                     9.000000
# 3                     8.558678
# 4                     7.485775

# %% [markdown]
# ### Grafica

# %%
DF_VS=pd.merge(G_data[['Día natural', 'Kilos Venta KG']] , G_stock[['Día natural','Vida Útil Restante Promedio', 'Stock']]  
     , how='right')
DF_VS.sort_values(by=['Día natural'], inplace=True)
DF_VS.head()
# Out:
#   Día natural  Kilos Venta KG  Vida Útil Restante Promedio     Stock
# 0  2019-11-27         19736.0                     8.177941  208560.8
# 1  2019-11-28         44687.0                     8.355210  165123.1
# 2  2019-11-29         27747.0                     9.000000  138677.0
# 3  2019-11-30         24920.0                     8.558678  129420.3
# 4  2019-12-02         16344.0                     7.485775  132351.0

# %%
from mizani.breaks import date_breaks
from mizani.formatters import date_format

# %%
GRaph_Disp_cluster=(
    ggplot(DF_VS, aes(x='Día natural',
                               y= 'Stock'))\
                #+ labs(y='Disposición a pagar',x='Tipo de Semana')\
                + geom_point(aes(color='Vida Útil Restante Promedio'
                     ))\
                 + geom_point(aes(x='Día natural',
                               y= 'Kilos Venta KG'))\
                +ggtitle(('Peso Promedio de los Clusters de Clientes'+
                          ' \n Para Cada Semana'))\
                +theme(axis_text_x = element_text(angle=90, hjust=1)
                       ,figure_size=(26,8))
                 #+ scale_x_continuous(breaks=X_brak,labels=X_brak_S)
                + scale_x_datetime(breaks=date_breaks('1 month'))  
    )
GRaph_Disp_cluster
# Out:
# C:\Users\rolft\Anaconda3\envs\BA\lib\site-packages\plotnine\layer.py:401: PlotnineWarning: geom_point : Removed 78 rows containing missing values.
# <ggplot: (122883567279)>

# %% [markdown]
# #### Analisis simple

# %%
DF_VS[DF_VS.Stock>=300000]['Día natural'].iloc[0]
# Out:
# datetime.date(2020, 3, 7)

# %%
Data_stock[Data_stock['Día natural']==
datetime.date(2020, 3, 7)]
# Out:
#     Sector Material Zona de ventas Oficina de ventas Oficina de ventas.1  \
# 85   Pollo  1010078       Santiago              T001          Huechuraba
# 421  Pollo  1010078       Santiago              T015              Quilin
# 576  Pollo  1010078       Santiago              T017           Lo Espejo
# 904  Pollo  1010078       Santiago              T022          Miraflores
#
#     Año natural/Semana Día natural  Vida Útil Restante     Stock  Semana  \
# 85             10.2020  2020-03-07                   2   94709.0      10
# 421            10.2020  2020-03-07                  -2   84417.5      10
# 576            10.2020  2020-03-07                   2  122703.8      10
# 904            10.2020  2020-03-07                  -1   29672.9      10
#
#       Año  Vida Útil Restante Promedio
# 85   2020                     189418.0
# 421  2020                    -168835.0
# 576  2020                     245407.6
# 904  2020                     -29672.9

# %%
G_data[G_data['Día natural']==
datetime.date(2020, 3, 7)]
# Out:
#     Día natural  Kilos Venta KG  Venta Neta CLP  Precio Promedio CLP  Semana  \
# 966  2020-03-07           21459        25132245               276613    2230
#
#         Año
# 966  450460

# %%
Data_stock[Data_stock['Día natural']==
datetime.date(2020, 3, 6)]
# Out:
#     Sector Material Zona de ventas Oficina de ventas Oficina de ventas.1  \
# 84   Pollo  1010078       Santiago              T001          Huechuraba
# 420  Pollo  1010078       Santiago              T015              Quilin
# 575  Pollo  1010078       Santiago              T017           Lo Espejo
# 903  Pollo  1010078       Santiago              T022          Miraflores
#
#     Año natural/Semana Día natural  Vida Útil Restante    Stock  Semana   Año  \
# 84             10.2020  2020-03-06                  10  26922.5      10  2020
# 420            10.2020  2020-03-06                  10    286.0      10  2020
# 575            10.2020  2020-03-06                  10  15144.3      10  2020
# 903            10.2020  2020-03-06                   7   8623.1      10  2020
#
#      Vida Útil Restante Promedio
# 84                      269225.0
# 420                       2860.0
# 575                     151443.0
# 903                      60361.7

# %%
GRaph_Disp_cluster=(
    ggplot(DF_VS, aes(x='Stock',
                               y= 'Kilos Venta KG' ))\
                + labs(y='Demanda',x='Stock')\
                + geom_point(aes(color='Vida Útil Restante Promedio'
                     ))\
                +ggtitle(('Peso Promedio de los Clusters de Clientes'+
                          ' \n Para Cada Semana'))
                 #+ scale_x_continuous(breaks=X_brak,labels=X_brak_S)
                #+ scale_x_datetime(breaks=date_breaks('1 month'))  
    )
GRaph_Disp_cluster
# Out:
# C:\Users\rolft\Anaconda3\envs\BA\lib\site-packages\plotnine\layer.py:401: PlotnineWarning: geom_point : Removed 78 rows containing missing values.
# <ggplot: (122877070746)>

# %%
(
    ggplot(Data_stock)
    + geom_boxplot(aes(x='Oficina de ventas.1', y='Vida Útil Restante'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
)
# Out:
# <ggplot: (122879627511)>

# %%
data.columns
# Out:
# Index(['Material', 'Tipo de cliente', 'Zona de ventas', 'Zona de ventas.1',
#        'Oficina de Ventas Unifica', 'Oficina de Ventas Unifica.1',
#        'Subtipo de cliente', 'Cluster', 'Cliente - Local', 'Cliente - Local.1',
#        'Mes', 'Año natural/Semana', 'Día natural', 'Día de la semana',
#        'Kilos Venta KG', 'Venta Neta CLP', 'Precio Promedio CLP', 'Semana',
#        'Año'],
#       dtype='object')

# %%
data.head(2)
# Out:
#   Material Tipo de cliente Zona de ventas Zona de ventas.1  \
# 0  1010078     Tradicional           Z001         Santiago
# 1  1010078     Tradicional           Z001         Santiago
#
#   Oficina de Ventas Unifica Oficina de Ventas Unifica.1 Subtipo de cliente  \
# 0                Huechuraba                        T101      Emprendedores
# 1                Huechuraba                        T101      Emprendedores
#
#    Cluster                  Cliente - Local Cliente - Local.1 Mes  \
# 0  Clásico   Gonzalez Ahumada Paola Eugenia        3200116471   4
# 1  Clásico   Gonzalez Ahumada Paola Eugenia        3200116471   8
#
#   Año natural/Semana Día natural Día de la semana  Kilos Venta KG  \
# 0            17.2020  2020-04-24               VI              22
# 1            34.2020  2020-08-18               MA              22
#
#    Venta Neta CLP  Precio Promedio CLP  Semana   Año
# 0           25380                 1150      17  2020
# 1           29304                 1320      34  2020

# %% [markdown]
# ###  Boxplot Demanda

# %%
(
    ggplot(data.groupby(['Día natural','Oficina de Ventas Unifica']).sum().reset_index())
    + geom_boxplot(aes(x='Oficina de Ventas Unifica', y='Kilos Venta KG'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
     +theme(axis_text_x = element_text(angle=90, hjust=1)
                      )
)
# Out:
# <ggplot: (122878526865)>

# %%
(
    ggplot(Cluster_df_vol.groupby(['Día natural','Oficina de Ventas Unifica']).sum().reset_index())
    + geom_boxplot(aes(x='Oficina de Ventas Unifica', y='Kilos Venta KG'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
     +theme(axis_text_x = element_text(angle=90, hjust=1)
                      )
)
# Out:
# <ggplot: (122879474935)>

# %% [markdown]
# # box segmento

# %%
DF_ventas.identified_clusters=DF_ventas.identified_clusters.dtype('int64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-a7a3db9ee37c> in <module>
# ----> 1 DF_ventas.identified_clusters=DF_ventas.identified_clusters.dtype('int64')
#
# TypeError: 'numpy.dtype[float64]' object is not callable

# %%
df_x=DF_ventas.copy()
df_x=df_x.dropna()

# %%
 def categoria(x):
        Segmento={'0':'Atractivo','1':'Oportunista','2':'Mayorista','3':'Oportunista menor','4':'Frecuente'}
        x=str(x)
        x=x[0]
        return Segmento[x]#.replace('.', '')
    

df_x['identified_clusters']=df_x['identified_clusters'].apply(categoria)

# %%
(
    ggplot(df_x.groupby(['Día natural','Oficina de Ventas Unifica','identified_clusters']).sum().reset_index())
    + geom_boxplot(aes(x='identified_clusters', y='Kilos Venta KG'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
     +theme(axis_text_x = element_text(angle=90, hjust=1)
                      )
     + facet_grid('.~Oficina de Ventas Unifica')\
)
# Out:
# <ggplot: (122887023478)>

# %%
df_x.groupby(['Día natural','Oficina de Ventas Unifica','identified_clusters']).count()#.reset_index()
# Out:
#                                                            Cliente - Local.1  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                    2
#                                       1                                    1
#                                       2                                    1
#                                       4                                    9
#             Lo Espejo                 0                                    1
# ...                                                                      ...
# 2021-02-11  Sucursal Miraflores       0                                   12
#                                       1                                   28
#                                       2                                    6
#                                       3                                    9
#                                       4                                   65
#
#                                                            Material  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                           2
#                                       1                           1
#                                       2                           1
#                                       4                           9
#             Lo Espejo                 0                           1
# ...                                                             ...
# 2021-02-11  Sucursal Miraflores       0                          12
#                                       1                          28
#                                       2                           6
#                                       3                           9
#                                       4                          65
#
#                                                            Tipo de cliente  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                  2
#                                       1                                  1
#                                       2                                  1
#                                       4                                  9
#             Lo Espejo                 0                                  1
# ...                                                                    ...
# 2021-02-11  Sucursal Miraflores       0                                 12
#                                       1                                 28
#                                       2                                  6
#                                       3                                  9
#                                       4                                 65
#
#                                                            Zona de ventas  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                 2
#                                       1                                 1
#                                       2                                 1
#                                       4                                 9
#             Lo Espejo                 0                                 1
# ...                                                                   ...
# 2021-02-11  Sucursal Miraflores       0                                12
#                                       1                                28
#                                       2                                 6
#                                       3                                 9
#                                       4                                65
#
#                                                            Zona de ventas.1  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                   2
#                                       1                                   1
#                                       2                                   1
#                                       4                                   9
#             Lo Espejo                 0                                   1
# ...                                                                     ...
# 2021-02-11  Sucursal Miraflores       0                                  12
#                                       1                                  28
#                                       2                                   6
#                                       3                                   9
#                                       4                                  65
#
#                                                            Oficina de Ventas Unifica.1  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                              2
#                                       1                                              1
#                                       2                                              1
#                                       4                                              9
#             Lo Espejo                 0                                              1
# ...                                                                                ...
# 2021-02-11  Sucursal Miraflores       0                                             12
#                                       1                                             28
#                                       2                                              6
#                                       3                                              9
#                                       4                                             65
#
#                                                            Subtipo de cliente  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                     2
#                                       1                                     1
#                                       2                                     1
#                                       4                                     9
#             Lo Espejo                 0                                     1
# ...                                                                       ...
# 2021-02-11  Sucursal Miraflores       0                                    12
#                                       1                                    28
#                                       2                                     6
#                                       3                                     9
#                                       4                                    65
#
#                                                            Cluster  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                          2
#                                       1                          1
#                                       2                          1
#                                       4                          9
#             Lo Espejo                 0                          1
# ...                                                            ...
# 2021-02-11  Sucursal Miraflores       0                         12
#                                       1                         28
#                                       2                          6
#                                       3                          9
#                                       4                         65
#
#                                                            Cliente - Local  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                  2
#                                       1                                  1
#                                       2                                  1
#                                       4                                  9
#             Lo Espejo                 0                                  1
# ...                                                                    ...
# 2021-02-11  Sucursal Miraflores       0                                 12
#                                       1                                 28
#                                       2                                  6
#                                       3                                  9
#                                       4                                 65
#
#                                                            Mes  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                      2
#                                       1                      1
#                                       2                      1
#                                       4                      9
#             Lo Espejo                 0                      1
# ...                                                        ...
# 2021-02-11  Sucursal Miraflores       0                     12
#                                       1                     28
#                                       2                      6
#                                       3                      9
#                                       4                     65
#
#                                                            Año natural/Semana  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                     2
#                                       1                                     1
#                                       2                                     1
#                                       4                                     9
#             Lo Espejo                 0                                     1
# ...                                                                       ...
# 2021-02-11  Sucursal Miraflores       0                                    12
#                                       1                                    28
#                                       2                                     6
#                                       3                                     9
#                                       4                                    65
#
#                                                            Día de la semana  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                   2
#                                       1                                   1
#                                       2                                   1
#                                       4                                   9
#             Lo Espejo                 0                                   1
# ...                                                                     ...
# 2021-02-11  Sucursal Miraflores       0                                  12
#                                       1                                  28
#                                       2                                   6
#                                       3                                   9
#                                       4                                  65
#
#                                                            Kilos Venta KG  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                 2
#                                       1                                 1
#                                       2                                 1
#                                       4                                 9
#             Lo Espejo                 0                                 1
# ...                                                                   ...
# 2021-02-11  Sucursal Miraflores       0                                12
#                                       1                                28
#                                       2                                 6
#                                       3                                 9
#                                       4                                65
#
#                                                            Venta Neta CLP  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                 2
#                                       1                                 1
#                                       2                                 1
#                                       4                                 9
#             Lo Espejo                 0                                 1
# ...                                                                   ...
# 2021-02-11  Sucursal Miraflores       0                                12
#                                       1                                28
#                                       2                                 6
#                                       3                                 9
#                                       4                                65
#
#                                                            Precio Promedio CLP  \
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                                      2
#                                       1                                      1
#                                       2                                      1
#                                       4                                      9
#             Lo Espejo                 0                                      1
# ...                                                                        ...
# 2021-02-11  Sucursal Miraflores       0                                     12
#                                       1                                     28
#                                       2                                      6
#                                       3                                      9
#                                       4                                     65
#
#                                                            Semana  Año
# Día natural Oficina de Ventas Unifica identified_clusters
# 2017-01-03  Huechuraba                0                         2    2
#                                       1                         1    1
#                                       2                         1    1
#                                       4                         9    9
#             Lo Espejo                 0                         1    1
# ...                                                           ...  ...
# 2021-02-11  Sucursal Miraflores       0                        12   12
#                                       1                        28   28
#                                       2                         6    6
#                                       3                         9    9
#                                       4                        65   65
#
# [16463 rows x 17 columns]

# %%
(
    ggplot(df_x.groupby(['Día natural','Oficina de Ventas Unifica','identified_clusters']).count().reset_index())
    + geom_boxplot(aes(x='identified_clusters', y='Kilos Venta KG'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
     +theme(axis_text_x = element_text(angle=90, hjust=1)
                      )
     + facet_grid('.~Oficina de Ventas Unifica')\
    +ggtitle('Diario')+ labs(x='Sucursal y Segmento', y='Cantidad de clientes')
)
# Out:
# <ggplot: (122879804862)>

# %%
(
    ggplot(df_x.groupby(['Año natural/Semana','Oficina de Ventas Unifica','identified_clusters']).count().reset_index())
    + geom_boxplot(aes(x='identified_clusters', y='Kilos Venta KG'))
    #+ scale_x_discrete(labels=months, name='month')  # change ticks labels on OX
     +theme(axis_text_x = element_text(angle=90, hjust=1)
                      )
     + facet_grid('.~Oficina de Ventas Unifica')    
        +ggtitle('Semanal')+ labs(x='Sucursal y Segmento', y='Cantidad de clientes')
)
# Out:
# <ggplot: (122879805181)>
